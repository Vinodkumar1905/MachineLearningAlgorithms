# %%
import pandas as pd
import numpy as np 
from utilities import hotEncode
data = pd.read_csv("./Data/Data.csv")

# %%
print(data["propertytype"].unique())
data.head()
# Out:
# ['Flat' 'Villa' 'House']
#    bhk propertytype   location   sqft  pricepersqft  totalprice
# 0    3         Flat  Ahmedabad   1346          6233    15700000
# 1    4         Flat  Ahmedabad   1872          4873    17500000
# 2    4         Flat  Ahmedabad   1650          6733    20200000
# 3    5         Flat  Ahmedabad  10201          8499    86700000
# 4    3         Flat  Ahmedabad    968          5944    10400000

# %%
sampleData =  hotEncode(data,"propertytype",True)
sampleData.head()
# Out:
#    bhk   location  ...  propertytype_House  propertytype_Villa
# 0    3  Ahmedabad  ...                   0                   0
# 1    4  Ahmedabad  ...                   0                   0
# 2    4  Ahmedabad  ...                   0                   0
# 3    5  Ahmedabad  ...                   0                   0
# 4    3  Ahmedabad  ...                   0                   0
#
# [5 rows x 8 columns]

# %%
sampleData.to_csv("./Data/finalData.csv")

# %%
sampleData.info()
sampleData["location"].unique()
cities = sampleData["location"].unique()
cities
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14119 entries, 0 to 14118
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bhk                 14119 non-null  int64
#  1   location            14119 non-null  object
#  2   sqft                14119 non-null  int64
#  3   pricepersqft        14119 non-null  int64
#  4   totalprice          14119 non-null  int64
#  5   propertytype_Flat   14119 non-null  int64
#  6   propertytype_House  14119 non-null  int64
#  7   propertytype_Villa  14119 non-null  int64
# dtypes: int64(7), object(1)
# memory usage: 882.6+ KB
# array(['Ahmedabad', 'Amritsar', 'Bangalore', 'Bhilai', 'Bhopal',
#        'Bhubaneswar', 'Bilaspur', 'Chennai', 'Coimbatore', 'Cuttack',
#        'Dehradun', 'Dhanbad', 'Durgapur', 'Dwarka', 'Ernakulam',
#        'Faridabad', 'Gurgaon', 'Guwahati', 'Gwalior', 'Haridwar',
#        'Howrah', 'Hyderabad', 'Indore', 'Jaipur', 'Jalandhar',
# ...

# %%
for city in cities:
    newData = sampleData[sampleData["location"]==city]
    print(newData)
# Out:
#      bhk   location  ...  propertytype_House  propertytype_Villa
# 0      3  Ahmedabad  ...                   0                   0
# 1      4  Ahmedabad  ...                   0                   0
# 2      4  Ahmedabad  ...                   0                   0
# 3      5  Ahmedabad  ...                   0                   0
# 4      3  Ahmedabad  ...                   0                   0
# ..   ...        ...  ...                 ...                 ...
# 285    1  Ahmedabad  ...                   0                   0
# 286    3  Ahmedabad  ...                   0                   0
# 287    3  Ahmedabad  ...                   0                   0
# 288    3  Ahmedabad  ...                   1                   0
# 289    2  Ahmedabad  ...                   1                   0
#
# [290 rows x 8 columns]
#      bhk  location  ...  propertytype_House  propertytype_Villa
# 290    2  Amritsar  ...                   1                   0
# ...
